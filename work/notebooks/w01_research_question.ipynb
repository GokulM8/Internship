# %% [markdown]
# <a href="https://colab.research.google.com/github/GokulM8/Internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ## My Lane: Refresh / Content Opportunity Scoring
#
# I chose the **Refresh / Content Opportunity Scoring** lane because it addresses a practical SEO problem: identifying which webpages should be reviewed and updated first when resources are limited. This lane aligns with the internship's machine learning pipeline and provides a clear opportunity to apply feature engineering, classification, and ranking techniques to generate a prioritized refresh queue. It also allows me to build a solution that is both technically robust and directly useful for decision-making.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ## Research Question
#
# **Decision**
#
# Which webpages should be prioritized for content refresh to improve organic search performance?
#
# **Action**
#
# SEO managers or content teams use the ranked refresh queue to decide which pages to review, update, expand, or monitor.
#
# **Cost of a Wrong Recommendation**
#
# If the model recommends the wrong pages, valuable time and resources may be spent updating content that does not need improvement, while pages with genuine refresh opportunities may continue to lose visibility and traffic.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os
print(os.getcwd())
# Out:
# /content/Internship

# %%
# !ls
# Out:
# AGENTS.md  DATA_USE.md	LICENSE    README.md	     SETUP.md	 work
# CLAUDE.md  docs		notebooks  requirements.txt  skills
# data	   GUIDE.md	outputs    scripts	     submission

# %%
import os

if not os.path.exists("Internship"):
    # !git clone https://github.com/GokulM8/Internship.git

os.chdir("Internship")

print("Current directory:", os.getcwd())
# !ls
# Out:
# Cloning into 'Internship'...
# remote: Enumerating objects: 110, done.
# remote: Counting objects: 100% (110/110), done.
# remote: Compressing objects: 100% (81/81), done.
# remote: Total 110 (delta 27), reused 79 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (110/110), 1.87 MiB | 24.82 MiB/s, done.
# Resolving deltas: 100% (27/27), done.
# Current directory: /content/Internship/Internship
# AGENTS.md  DATA_USE.md	LICENSE    README.md	     SETUP.md	 work
# CLAUDE.md  docs		notebooks  requirements.txt  skills
# data	   GUIDE.md	outputs    scripts	     submission

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print(f"Total pages: {len(df):,}")
print(f"Average CTR: {df['ctr'].mean():.3f}")
print(f"Average content age (days): {df['content_age_days'].mean():.1f}")

print("\nTrend Direction Distribution")
print(df["trend_direction"].value_counts())
# Out:
# Total pages: 30,000
# Average CTR: 0.511
# Average content age (days): 256.2
#
# Trend Direction Distribution
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ## What I Can and Cannot Claim
#
# This project provides **observed, measured, and decision-support insights** based on the available anonymized dataset. The resulting refresh scores and recommendations indicate which pages may deserve higher review priority under similar conditions.
#
# This project **does not prove causal relationships**, reveal Google's ranking algorithm, or guarantee future search performance. All findings should be interpreted as data-driven recommendations rather than definitive predictions.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
